# %% [markdown]
# # Курсовая работа Deep Learning

# %% [markdown]
# ## Variant - 2
# ### Исследование применимости автокодировщиков к решению задачи предсказания времени поломки оборудования.

# %% [markdown]
# #### Задача прогнозирования поломок имеет целью уменьшить риски использования неисправного оборудования, что позволит увеличить безопасность эксплуатации и снизить расходы. В процессе эксплуатации оборудования, как правило, производится периодический сбор различных параметров с помощью датчиков. Эти параметры могут использоваться для прогнозирования сроков службы. Вам предлагается применить нейросетевые модели автокодировщиков для оценки момента выхода оборудования из строя в предположении, что непосредственно перед поломкой показания датчиков становятся аномальными (и, следовательно, увеличивается ошибка реконструкции автокодировщика).

# %% [markdown]
# #### Выполнили: Захаров Д.А. Щукин А.А.
# #### Группа ИВТ-360

# %% [markdown]
# ### *Этап 1 - Установка библиотек*

# %%
import glob
import numpy as np
import pandas as pd
import plotly.express as px
import plotly.graph_objs as go
import plotly as pl
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, RobustScaler, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.datasets import make_classification
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

#%load_ext tensorboard
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))


# gpus = tf.config.experimental.list_physical_devices('GPU')
# if gpus:
#   try:
#     tf.config.experimental.set_virtual_device_configuration(
#         gpus[0],[tf.config.experimental.VirtualDeviceConfiguration(memory_limit=5120)])
#   except RuntimeError as e:
#     print(e)
# Out:
# Num GPUs Available:  0

# %% [markdown]
# ### *Этап 2 - Загрузка датасета*
# *Загружаем только train, т.к. только в данных датасетах есть гарантия, что деталь вышла из строя*

# %%
X1 = pd.read_csv("C:/MyLabProjects/DeepLearning/Course_Work_DL/CMaps/Convret/train_FD001.csv")
X2 = pd.read_csv("C:/MyLabProjects/DeepLearning/Course_Work_DL/CMaps/Convret/train_FD002.csv")
X3 = pd.read_csv("C:/MyLabProjects/DeepLearning/Course_Work_DL/CMaps/Convret/train_FD003.csv")
X4 = pd.read_csv("C:/MyLabProjects/DeepLearning/Course_Work_DL/CMaps/Convret/train_FD004.csv")

# %% [markdown]
# *Объеденим данные по каждому объекту*

# %%
# X1 = pd.concat([X1_test, X1_train])
# X2 = pd.concat([X2_test, X2_train])
# X3 = pd.concat([X3_test, X3_train])
# X4 = pd.concat([X4_test, X4_train])

# %%
X1
# Out:
#        unit number  time in cycles  operational setting 1
# 0                1               1                -0.0007  \
# 1                1               2                 0.0019
# 2                1               3                -0.0043
# 3                1               4                 0.0007
# 4                1               5                -0.0019
# ...            ...             ...                    ...
# 20626          100             196                -0.0004
# 20627          100             197                -0.0016
# 20628          100             198                 0.0004
# 20629          100             199                -0.0011
# 20630          100             200                -0.0032
#
#        operational setting 2  operational setting 3  sensor measurement 1
# 0                    -0.0004                  100.0                518.67  \
# 1                    -0.0003                  100.0                518.67
# 2                     0.0003                  100.0                518.67
# 3                     0.0000                  100.0                518.67
# 4                    -0.0002                  100.0                518.67
# ...                      ...                    ...                   ...
# 20626                -0.0003                  100.0                518.67
# 20627                -0.0005                  100.0                518.67
# 20628                 0.0000                  100.0                518.67
# 20629                 0.0003                  100.0                518.67
# 20630                -0.0005                  100.0                518.67
#
#        sensor measurement 2  sensor measurement 3  sensor measurement 4
# 0                    641.82               1589.70               1400.60  \
# 1                    642.15               1591.82               1403.14
# 2                    642.35               1587.99               1404.20
# 3                    642.35               1582.79               1401.87
# 4                    642.37               1582.85               1406.22
# ...                     ...                   ...                   ...
# 20626                643.49               1597.98               1428.63
# 20627                643.54               1604.50               1433.58
# 20628                643.42               1602.46               1428.18
# 20629                643.23               1605.26               1426.53
# 20630                643.85               1600.38               1432.14
#
#        sensor measurement 5  ...  sensor measurement 12
# 0                     14.62  ...                 521.66  \
# 1                     14.62  ...                 522.28
# 2                     14.62  ...                 522.42
# 3                     14.62  ...                 522.86
# 4                     14.62  ...                 522.19
# ...                     ...  ...                    ...
# 20626                 14.62  ...                 519.49
# 20627                 14.62  ...                 519.68
# 20628                 14.62  ...                 520.01
# 20629                 14.62  ...                 519.67
# 20630                 14.62  ...                 519.30
#
#        sensor measurement 13  sensor measurement 14  sensor measurement 15
# 0                    2388.02                8138.62                 8.4195  \
# 1                    2388.07                8131.49                 8.4318
# 2                    2388.03                8133.23                 8.4178
# 3                    2388.08                8133.83                 8.3682
# 4                    2388.04                8133.80                 8.4294
# ...                      ...                    ...                    ...
# 20626                2388.26                8137.60                 8.4956
# 20627                2388.22                8136.50                 8.5139
# 20628                2388.24                8141.05                 8.5646
# 20629                2388.23                8139.29                 8.5389
# 20630                2388.26                8137.33                 8.5036
#
#        sensor measurement 16  sensor measurement 17  sensor measurement 18
# 0                       0.03                    392                   2388  \
# 1                       0.03                    392                   2388
# 2                       0.03                    390                   2388
# 3                       0.03                    392                   2388
# 4                       0.03                    393                   2388
# ...                      ...                    ...                    ...
# 20626                   0.03                    397                   2388
# 20627                   0.03                    395                   2388
# 20628                   0.03                    398                   2388
# 20629                   0.03                    395                   2388
# 20630                   0.03                    396                   2388
#
#        sensor measurement 19  sensor measurement 20  sensor measurement 21
# 0                      100.0                  39.06                23.4190
# 1                      100.0                  39.00                23.4236
# 2                      100.0                  38.95                23.3442
# 3                      100.0                  38.88                23.3739
# 4                      100.0                  38.90                23.4044
# ...                      ...                    ...                    ...
# 20626                  100.0                  38.49                22.9735
# 20627                  100.0                  38.30                23.1594
# 20628                  100.0                  38.44                22.9333
# 20629                  100.0                  38.29                23.0640
# 20630                  100.0                  38.37                23.0522
#
# [20631 rows x 26 columns]

# %% [markdown]
# ## *Разведочный анализ данных*

# %% [markdown]
# ### *Визуализируем данные с помощью метода t-SNE*
#
# *t-SNE - (встраивание стохастических соседей с t-распределением) нелинейный метод уменьшения размерности данных. Метод неконтролируемого нелинейного уменьшения размерности. Нелинейное уменьшение размерности означает, что алгоритм позволяет нам разделить данные, которые нельзя разделить прямой линией.*
#
# #### *Алгоритм t-SNE находит меру сходства между парами экземпляров в пространстве большей и меньшей размерности. После этого он пытается оптимизировать две меры сходства. Все это делается в три шага:*
#
#     1.t-SNE моделирует точку, выбранную в качестве соседа другой точки как в более высоких, так и в более низких измерениях. Он начинается с вычисления попарного сходства между всеми точками данных в многомерном пространстве с использованием ядра Гаусса. Точки, которые находятся далеко друг от друга, имеют меньшую вероятность быть выбранными, чем точки, которые расположены близко друг к другу.
#
#     2.Затем алгоритм пытается сопоставить точки данных более высокой размерности с пространством более низкой размерности, сохраняя при этом попарное сходство.
#
#     3.Это достигается за счет минимизации расхождения между вероятностным распределением исходного высокоразмерного и низкоразмерного. Алгоритм использует градиентный спуск, чтобы минимизировать расхождение. Вложение более низкой размерности оптимизируется до стабильного состояния.
#
# #### *Процесс оптимизации позволяет создавать кластеры и подкластеры похожих точек данных в пространстве более низкого измерения, которые визуализируются для понимания структуры и взаимосвязи в данных более высокого измерения.*

# %%
# X1emb = TSNE(n_components=3, learning_rate='auto', init='random', perplexity=3).fit_transform(X1)

# %%
# X1emb_pd = pd.DataFrame(X1emb)
# X1emb_pd

# %%
# X1emb_pd.columns = ['col1', 'col2', 'col3']
# X1emb_pd

# %%
# fig1 = go.Scatter3d(x = X1emb_pd['col1'], y = X1emb_pd['col2'], z = X1emb_pd['col3'], 
#                                                                                     marker=dict(opacity=0.9,
#                                                                                     reversescale=True,
#                                                                                     colorscale='Blues',
#                                                                                     size=5),
#                                                                                     line=dict (width=0.02), 
#                                                                                     mode = 'markers')

# mylayout = go.Layout(scene=dict(xaxis = dict(title = "col1"), yaxis = dict(title = "col2"), zaxis = dict(title = "col3")))

# pl.offline.plot({"data": [fig1], "layout": mylayout}, auto_open = True)
# Out:
# 'temp-plot.html'

# %% [markdown]
# ### *Попытки представить данные в виде 3х-мерных графиков*
# *Operational settings (3 столбца) будем изображать на графике с помощью форм (круг, квадрат, треугольник соответствено), тем самым отображая 3 измерения в 1*

# %%
markersize = X1['operational setting 1'] + 10
markercolor = (X1['operational setting 2'] + 0.005) * 1000
#markershape = X1['operational setting 3'].replace("square")

fig1 = go.Scatter3d(x = X1['unit number'], y = X1['time in cycles'], z = X1['sensor measurement 7'],
                                                                                    marker=dict(size=markersize,
                                                                                                                color = markercolor,
                                                                                                                #symbol = markershape,
                                                                                                                opacity = 0.9,
                                                                                                                reversescale = True,
                                                                                                                colorscale = 'Blues'),
                                                                                    line=dict(width=0.02), 
                                                                                    mode = 'markers')

mylayout = go.Layout(scene=dict(xaxis = dict(title = "unit number"), yaxis = dict(title = "time in cycles"), zaxis = dict(title = "sensor measurement")))

pl.offline.plot({"data": [fig1], "layout": mylayout}, auto_open = True)
# Out:
# 'temp-plot.html'

# %% [markdown]
# ### *Представим данные отдельных столбцов в виде графиков*

# %% [markdown]
# #### *Time in cycles*

# %%
# X1_train["time in cycles"].hist(bins=50)
sns.displot(X1["time in cycles"])

# %% [markdown]
# #### *Operational settings [1 - 3]*

# %%
# X1_train["operational setting 1"].hist(bins=50)
sns.displot(X1["operational setting 1"])

# %%
# X1_train["operational setting 2"].hist(bins=50)
sns.displot(X1["operational setting 2"])

# %%
# X1_train["operational setting 3"].hist(bins=50)
sns.displot(X1["operational setting 2"])

# %% [markdown]
# #### *Sensor measurements [1 - 26]*

# %%
X1["sensor measurement 1"].hist(bins=50)
#sns.displot(X1_train["sensor measurement 1"], kind='ecdf')
# Out:
# <AxesSubplot: >

# %%
sns.displot(X1["sensor measurement 2"])
# X1_train["sensor measurement 2"].hist(bins=50)

# %%
sns.displot(X1["sensor measurement 3"])
# X1_train["sensor measurement 3"].hist(bins=50)

# %%
sns.displot(X1["sensor measurement 4"])
# X1_train["sensor measurement 4"].hist(bins=50)

# %%
#sns.displot(X1_train["sensor measurement 5"], kind='ecdf')
X1["sensor measurement 5"].hist(bins=50)
# Out:
# <AxesSubplot: >

# %%
# X1_train["sensor measurement 6"].hist(bins=50)
sns.displot(X1["sensor measurement 6"])

# %%
# X1_train["sensor measurement 7"].hist(bins=50)
sns.displot(X1["sensor measurement 7"])

# %%
# X1_train["sensor measurement 8"].hist(bins=50)
sns.displot(X1["sensor measurement 8"])

# %%
#X1_train["sensor measurement 9"].hist(bins=50)
sns.displot(X1["sensor measurement 9"])

# %%
X1["sensor measurement 10"].hist(bins=50)
# Out:
# <AxesSubplot: >

# %%
# X1_train["sensor measurement 11"].hist(bins=50)
sns.displot(X1["sensor measurement 11"])

# %%
# X1_train["sensor measurement 12"].hist(bins=50)
sns.displot(X1["sensor measurement 12"])

# %%
# X1_train["sensor measurement 13"].hist(bins=50)
sns.displot(X1["sensor measurement 13"])

# %%
# X1_train["sensor measurement 14"].hist(bins=50)
sns.displot(X1["sensor measurement 14"])

# %%
# X1_train["sensor measurement 15"].hist(bins=50)
sns.displot(X1["sensor measurement 15"])

# %%
X1["sensor measurement 16"].hist(bins=50)
# Out:
# <AxesSubplot: >

# %%
# X1_train["sensor measurement 17"].hist(bins=50)
sns.displot(X1["sensor measurement 17"], kde=True)

# %%
X1["sensor measurement 18"].hist(bins=50)
# Out:
# <AxesSubplot: >

# %%
X1["sensor measurement 19"].hist(bins=50)
# Out:
# <AxesSubplot: >

# %%
# X1_train["sensor measurement 20"].hist(bins=50)
sns.displot(X1["sensor measurement 20"], kde=True)

# %%
# X1_train["sensor measurement 21"].hist(bins=50)
sns.displot(data = X1, x = "sensor measurement 21", hue="unit number", multiple="stack")

# %% [markdown]
# ### *Представим данные ПОКАЗАТЕЛЕЙ ДАТЧИКОВ от ВРЕМЕНИ В ЦИКЛАХ в виде графиков*

# %%
sns.lineplot(x = "time in cycles", y = "sensor measurement 1", data = X1)
# Out:
# <AxesSubplot: xlabel='time in cycles', ylabel='sensor measurement 1'>

# %%
sns.lineplot(x = "time in cycles", y = "sensor measurement 2", data = X1)
# Out:
# <AxesSubplot: xlabel='time in cycles', ylabel='sensor measurement 2'>

# %%
sns.lineplot(x = "time in cycles", y = "sensor measurement 3", data = X1)
# Out:
# <AxesSubplot: xlabel='time in cycles', ylabel='sensor measurement 3'>

# %%
sns.lineplot(x = "time in cycles", y = "sensor measurement 4", data = X1)
# Out:
# <AxesSubplot: xlabel='time in cycles', ylabel='sensor measurement 4'>

# %%
sns.lineplot(x = "time in cycles", y = "sensor measurement 5", data = X1)
# Out:
# <AxesSubplot: xlabel='time in cycles', ylabel='sensor measurement 5'>

# %%
sns.lineplot(x = "time in cycles", y = "sensor measurement 6", data = X1)
# Out:
# <AxesSubplot: xlabel='time in cycles', ylabel='sensor measurement 6'>

# %%
sns.lineplot(x = "time in cycles", y = "sensor measurement 7", data = X1)
# Out:
# <AxesSubplot: xlabel='time in cycles', ylabel='sensor measurement 7'>

# %%
sns.lineplot(x = "time in cycles", y = "sensor measurement 8", data = X1)
# Out:
# <AxesSubplot: xlabel='sensor measurement 8', ylabel='time in cycles'>

# %%
sns.lineplot(x = "time in cycles", y = "sensor measurement 9", data = X1)
# Out:
# <AxesSubplot: xlabel='sensor measurement 9', ylabel='time in cycles'>

# %%
sns.lineplot(x = "time in cycles", y = "sensor measurement 10", data = X1)
# Out:
# <AxesSubplot: xlabel='time in cycles', ylabel='sensor measurement 10'>

# %%
sns.lineplot(x = "time in cycles", y = "sensor measurement 11", data = X1)
# Out:
# <AxesSubplot: xlabel='time in cycles', ylabel='sensor measurement 11'>

# %%
sns.lineplot(x = "time in cycles", y = "sensor measurement 12", data = X1)
# Out:
# <AxesSubplot: xlabel='time in cycles', ylabel='sensor measurement 12'>

# %%
sns.lineplot(x = "time in cycles", y = "sensor measurement 13", data = X1)
# Out:
# <AxesSubplot: xlabel='time in cycles', ylabel='sensor measurement 13'>

# %%
sns.lineplot(x = "time in cycles", y = "sensor measurement 14", data = X1)
# Out:
# <AxesSubplot: xlabel='time in cycles', ylabel='sensor measurement 14'>

# %%
sns.lineplot(x = "time in cycles", y = "sensor measurement 15", data = X1)
# Out:
# <AxesSubplot: xlabel='time in cycles', ylabel='sensor measurement 15'>

# %%
sns.lineplot(x = "time in cycles", y = "sensor measurement 16", data = X1)
# Out:
# <AxesSubplot: xlabel='time in cycles', ylabel='sensor measurement 16'>

# %%
sns.lineplot(x = "time in cycles", y = "sensor measurement 17", data = X1)
# Out:
# <AxesSubplot: xlabel='time in cycles', ylabel='sensor measurement 17'>

# %%
sns.lineplot(x = "time in cycles", y = "sensor measurement 18", data = X1)
# Out:
# <AxesSubplot: xlabel='time in cycles', ylabel='sensor measurement 18'>

# %%
sns.lineplot(x = "time in cycles", y = "sensor measurement 19", data = X1)
# Out:
# <AxesSubplot: xlabel='time in cycles', ylabel='sensor measurement 19'>

# %%
sns.lineplot(x = "time in cycles", y = "sensor measurement 20", data = X1)
# Out:
# <AxesSubplot: xlabel='time in cycles', ylabel='sensor measurement 20'>

# %%
sns.lineplot(x = "time in cycles", y = "sensor measurement 21", data = X1)
# Out:
# <AxesSubplot: xlabel='time in cycles', ylabel='sensor measurement 21'>

# %%
sns.jointplot(
    x = "time in cycles",
    y = "sensor measurement 21",
    data = X1,
    kind = 'kde',
    fill = True
)

# %%
sns.jointplot(
    x = "unit number",
    y = "sensor measurement 21",
    data = X1,
    kind = 'kde',
    fill = True
)

# %% [markdown]
# ## *Предобработка данных*

# %%
from sklearn import preprocessing

# %%
X1
# Out:
#        unit number  time in cycles  operational setting 1
# 0                1               1                -0.0007  \
# 1                1               2                 0.0019
# 2                1               3                -0.0043
# 3                1               4                 0.0007
# 4                1               5                -0.0019
# ...            ...             ...                    ...
# 20626          100             196                -0.0004
# 20627          100             197                -0.0016
# 20628          100             198                 0.0004
# 20629          100             199                -0.0011
# 20630          100             200                -0.0032
#
#        operational setting 2  operational setting 3  sensor measurement 1
# 0                    -0.0004                  100.0                518.67  \
# 1                    -0.0003                  100.0                518.67
# 2                     0.0003                  100.0                518.67
# 3                     0.0000                  100.0                518.67
# 4                    -0.0002                  100.0                518.67
# ...                      ...                    ...                   ...
# 20626                -0.0003                  100.0                518.67
# 20627                -0.0005                  100.0                518.67
# 20628                 0.0000                  100.0                518.67
# 20629                 0.0003                  100.0                518.67
# 20630                -0.0005                  100.0                518.67
#
#        sensor measurement 2  sensor measurement 3  sensor measurement 4
# 0                    641.82               1589.70               1400.60  \
# 1                    642.15               1591.82               1403.14
# 2                    642.35               1587.99               1404.20
# 3                    642.35               1582.79               1401.87
# 4                    642.37               1582.85               1406.22
# ...                     ...                   ...                   ...
# 20626                643.49               1597.98               1428.63
# 20627                643.54               1604.50               1433.58
# 20628                643.42               1602.46               1428.18
# 20629                643.23               1605.26               1426.53
# 20630                643.85               1600.38               1432.14
#
#        sensor measurement 5  ...  sensor measurement 12
# 0                     14.62  ...                 521.66  \
# 1                     14.62  ...                 522.28
# 2                     14.62  ...                 522.42
# 3                     14.62  ...                 522.86
# 4                     14.62  ...                 522.19
# ...                     ...  ...                    ...
# 20626                 14.62  ...                 519.49
# 20627                 14.62  ...                 519.68
# 20628                 14.62  ...                 520.01
# 20629                 14.62  ...                 519.67
# 20630                 14.62  ...                 519.30
#
#        sensor measurement 13  sensor measurement 14  sensor measurement 15
# 0                    2388.02                8138.62                 8.4195  \
# 1                    2388.07                8131.49                 8.4318
# 2                    2388.03                8133.23                 8.4178
# 3                    2388.08                8133.83                 8.3682
# 4                    2388.04                8133.80                 8.4294
# ...                      ...                    ...                    ...
# 20626                2388.26                8137.60                 8.4956
# 20627                2388.22                8136.50                 8.5139
# 20628                2388.24                8141.05                 8.5646
# 20629                2388.23                8139.29                 8.5389
# 20630                2388.26                8137.33                 8.5036
#
#        sensor measurement 16  sensor measurement 17  sensor measurement 18
# 0                       0.03                    392                   2388  \
# 1                       0.03                    392                   2388
# 2                       0.03                    390                   2388
# 3                       0.03                    392                   2388
# 4                       0.03                    393                   2388
# ...                      ...                    ...                    ...
# 20626                   0.03                    397                   2388
# 20627                   0.03                    395                   2388
# 20628                   0.03                    398                   2388
# 20629                   0.03                    395                   2388
# 20630                   0.03                    396                   2388
#
#        sensor measurement 19  sensor measurement 20  sensor measurement 21
# 0                      100.0                  39.06                23.4190
# 1                      100.0                  39.00                23.4236
# 2                      100.0                  38.95                23.3442
# 3                      100.0                  38.88                23.3739
# 4                      100.0                  38.90                23.4044
# ...                      ...                    ...                    ...
# 20626                  100.0                  38.49                22.9735
# 20627                  100.0                  38.30                23.1594
# 20628                  100.0                  38.44                22.9333
# 20629                  100.0                  38.29                23.0640
# 20630                  100.0                  38.37                23.0522
#
# [20631 rows x 26 columns]

# %%
X1_st = preprocessing.StandardScaler().fit(X1)
X1_st = X1_st.transform(X1)

X1_st = pd.DataFrame(X1_st)
X1_st.columns = ['unit number', 'time in cycles', 'operational setting 1', 'operational setting 2', 'operational setting 3', 'sensor measurement 1', 'sensor measurement 2', 'sensor measurement 3', 'sensor measurement 4', 'sensor measurement 5', 'sensor measurement 6', 'sensor measurement 7', 'sensor measurement 8', 'sensor measurement 9', 'sensor measurement 10', 'sensor measurement 11', 'sensor measurement 12', 'sensor measurement 13', 'sensor measurement 14', 'sensor measurement 15', 'sensor measurement 16', 'sensor measurement 17', 'sensor measurement 18', 'sensor measurement 19', 'sensor measurement 20', 'sensor measurement 21']

# %%
X1_st
# Out:
#        unit number  time in cycles  operational setting 1
# 0        -1.728084       -1.565170              -0.315980  \
# 1        -1.728084       -1.550652               0.872722
# 2        -1.728084       -1.536134              -1.961874
# 3        -1.728084       -1.521616               0.324090
# 4        -1.728084       -1.507098              -0.864611
# ...            ...             ...                    ...
# 20626     1.659204        1.265868              -0.178822
# 20627     1.659204        1.280386              -0.727453
# 20628     1.659204        1.294904               0.186933
# 20629     1.659204        1.309423              -0.498857
# 20630     1.659204        1.323941              -1.458962
#
#        operational setting 2  operational setting 3  sensor measurement 1
# 0                  -1.372953                    0.0                   0.0  \
# 1                  -1.031720                    0.0                   0.0
# 2                   1.015677                    0.0                   0.0
# 3                  -0.008022                    0.0                   0.0
# 4                  -0.690488                    0.0                   0.0
# ...                      ...                    ...                   ...
# 20626              -1.031720                    0.0                   0.0
# 20627              -1.714186                    0.0                   0.0
# 20628              -0.008022                    0.0                   0.0
# 20629               1.015677                    0.0                   0.0
# 20630              -1.714186                    0.0                   0.0
#
#        sensor measurement 2  sensor measurement 3  sensor measurement 4
# 0                 -1.721725             -0.134255             -0.925936  \
# 1                 -1.061780              0.211528             -0.643726
# 2                 -0.661813             -0.413166             -0.525953
# 3                 -0.661813             -1.261314             -0.784831
# 4                 -0.621816             -1.251528             -0.301518
# ...                     ...                   ...                   ...
# 20626              1.618000              1.216258              2.188375
# 20627              1.717992              2.279706              2.738351
# 20628              1.478011              1.946971              2.138377
# 20629              1.098043              2.403666              1.955051
# 20630              2.337940              1.607712              2.578358
#
#        sensor measurement 5  ...  sensor measurement 12
# 0             -1.776357e-15  ...               0.334262  \
# 1             -1.776357e-15  ...               1.174899
# 2             -1.776357e-15  ...               1.364721
# 3             -1.776357e-15  ...               1.961302
# 4             -1.776357e-15  ...               1.052871
# ...                     ...  ...                    ...
# 20626         -1.776357e-15  ...              -2.607969
# 20627         -1.776357e-15  ...              -2.350355
# 20628         -1.776357e-15  ...              -1.902919
# 20629         -1.776357e-15  ...              -2.363913
# 20630         -1.776357e-15  ...              -2.865584
#
#        sensor measurement 13  sensor measurement 14  sensor measurement 15
# 0                  -1.058890              -0.269071              -0.603816  \
# 1                  -0.363646              -0.642845              -0.275852
# 2                  -0.919841              -0.551629              -0.649144
# 3                  -0.224597              -0.520176              -1.971665
# 4                  -0.780793              -0.521748              -0.339845
# ...                      ...                    ...                    ...
# 20626               2.278282              -0.322542               1.425294
# 20627               1.722087              -0.380207               1.913240
# 20628               2.000184              -0.141684               3.265092
# 20629               1.861136              -0.233948               2.579834
# 20630               2.278282              -0.336696               1.638604
#
#        sensor measurement 16  sensor measurement 17  sensor measurement 18
# 0              -1.387779e-17              -0.781710                    0.0  \
# 1              -1.387779e-17              -0.781710                    0.0
# 2              -1.387779e-17              -2.073094                    0.0
# 3              -1.387779e-17              -0.781710                    0.0
# 4              -1.387779e-17              -0.136018                    0.0
# ...                      ...                    ...                    ...
# 20626          -1.387779e-17               2.446751                    0.0
# 20627          -1.387779e-17               1.155367                    0.0
# 20628          -1.387779e-17               3.092444                    0.0
# 20629          -1.387779e-17               1.155367                    0.0
# 20630          -1.387779e-17               1.801059                    0.0
#
#        sensor measurement 19  sensor measurement 20  sensor measurement 21
# 0                        0.0               1.348493               1.194427
# 1                        0.0               1.016528               1.236922
# 2                        0.0               0.739891               0.503423
# 3                        0.0               0.352598               0.777792
# 4                        0.0               0.463253               1.059552
# ...                      ...                    ...                    ...
# 20626                    0.0              -1.805173              -2.921113
# 20627                    0.0              -2.856395              -1.203764
# 20628                    0.0              -2.081810              -3.292481
# 20629                    0.0              -2.911722              -2.085072
# 20630                    0.0              -2.469103              -2.194080
#
# [20631 rows x 26 columns]

# %% [markdown]
# #### *Посмотрим на графики*

# %%
sns.displot(X1["sensor measurement 21"])
sns.displot(X1_st["sensor measurement 21"])

# %%
sns.kdeplot(data=X1, x="time in cycles", y="sensor measurement 21", fill = True)
# Out:
# <AxesSubplot: xlabel='time in cycles', ylabel='sensor measurement 21'>

# %%
sns.kdeplot(data=X1_st, x="time in cycles", y="sensor measurement 21", fill = True)
# Out:
# <AxesSubplot: xlabel='time in cycles', ylabel='sensor measurement 21'>

# %% [markdown]
# #### *Столбцы UNIT NUMBER и TIME IN CYCLES по сути не влияют на оценку поломки двигателей, поэтому их можно удалить.*

# %%
X1_st.drop(columns = X1_st.columns[0], axis= 1 , inplace= True)
X1_st.drop(columns = X1_st.columns[0], axis= 1 , inplace= True)

# %%
X1_st
# Out:
#        operational setting 1  operational setting 2  operational setting 3
# 0                  -0.315980              -1.372953                    0.0  \
# 1                   0.872722              -1.031720                    0.0
# 2                  -1.961874               1.015677                    0.0
# 3                   0.324090              -0.008022                    0.0
# 4                  -0.864611              -0.690488                    0.0
# ...                      ...                    ...                    ...
# 20626              -0.178822              -1.031720                    0.0
# 20627              -0.727453              -1.714186                    0.0
# 20628               0.186933              -0.008022                    0.0
# 20629              -0.498857               1.015677                    0.0
# 20630              -1.458962              -1.714186                    0.0
#
#        sensor measurement 1  sensor measurement 2  sensor measurement 3
# 0                       0.0             -1.721725             -0.134255  \
# 1                       0.0             -1.061780              0.211528
# 2                       0.0             -0.661813             -0.413166
# 3                       0.0             -0.661813             -1.261314
# 4                       0.0             -0.621816             -1.251528
# ...                     ...                   ...                   ...
# 20626                   0.0              1.618000              1.216258
# 20627                   0.0              1.717992              2.279706
# 20628                   0.0              1.478011              1.946971
# 20629                   0.0              1.098043              2.403666
# 20630                   0.0              2.337940              1.607712
#
#        sensor measurement 4  sensor measurement 5  sensor measurement 6
# 0                 -0.925936         -1.776357e-15              0.141683  \
# 1                 -0.643726         -1.776357e-15              0.141683
# 2                 -0.525953         -1.776357e-15              0.141683
# 3                 -0.784831         -1.776357e-15              0.141683
# 4                 -0.301518         -1.776357e-15              0.141683
# ...                     ...                   ...                   ...
# 20626              2.188375         -1.776357e-15              0.141683
# 20627              2.738351         -1.776357e-15              0.141683
# 20628              2.138377         -1.776357e-15              0.141683
# 20629              1.955051         -1.776357e-15              0.141683
# 20630              2.578358         -1.776357e-15              0.141683
#
#        sensor measurement 7  ...  sensor measurement 12
# 0                  1.121141  ...               0.334262  \
# 1                  0.431930  ...               1.174899
# 2                  1.008155  ...               1.364721
# 3                  1.222827  ...               1.961302
# 4                  0.714393  ...               1.052871
# ...                     ...  ...                    ...
# 20626             -2.189329  ...              -2.607969
# 20627             -2.833345  ...              -2.350355
# 20628             -2.742957  ...              -1.902919
# 20629             -3.036719  ...              -2.363913
# 20630             -2.912435  ...              -2.865584
#
#        sensor measurement 13  sensor measurement 14  sensor measurement 15
# 0                  -1.058890              -0.269071              -0.603816  \
# 1                  -0.363646              -0.642845              -0.275852
# 2                  -0.919841              -0.551629              -0.649144
# 3                  -0.224597              -0.520176              -1.971665
# 4                  -0.780793              -0.521748              -0.339845
# ...                      ...                    ...                    ...
# 20626               2.278282              -0.322542               1.425294
# 20627               1.722087              -0.380207               1.913240
# 20628               2.000184              -0.141684               3.265092
# 20629               1.861136              -0.233948               2.579834
# 20630               2.278282              -0.336696               1.638604
#
#        sensor measurement 16  sensor measurement 17  sensor measurement 18
# 0              -1.387779e-17              -0.781710                    0.0  \
# 1              -1.387779e-17              -0.781710                    0.0
# 2              -1.387779e-17              -2.073094                    0.0
# 3              -1.387779e-17              -0.781710                    0.0
# 4              -1.387779e-17              -0.136018                    0.0
# ...                      ...                    ...                    ...
# 20626          -1.387779e-17               2.446751                    0.0
# 20627          -1.387779e-17               1.155367                    0.0
# 20628          -1.387779e-17               3.092444                    0.0
# 20629          -1.387779e-17               1.155367                    0.0
# 20630          -1.387779e-17               1.801059                    0.0
#
#        sensor measurement 19  sensor measurement 20  sensor measurement 21
# 0                        0.0               1.348493               1.194427
# 1                        0.0               1.016528               1.236922
# 2                        0.0               0.739891               0.503423
# 3                        0.0               0.352598               0.777792
# 4                        0.0               0.463253               1.059552
# ...                      ...                    ...                    ...
# 20626                    0.0              -1.805173              -2.921113
# 20627                    0.0              -2.856395              -1.203764
# 20628                    0.0              -2.081810              -3.292481
# 20629                    0.0              -2.911722              -2.085072
# 20630                    0.0              -2.469103              -2.194080
#
# [20631 rows x 24 columns]

# %% [markdown]
# #### *Разделим датасет на Train и Test выборки.*
# *Аномальными значениями считаем 10 последних показателей для каждого UNIT NUMBER в датасете  Х1.*

# %% [markdown]
# #### *Добавим Validate выборку из X2, без аномальных значений*

# %%
X2
# Out:
#        unit number  time in cycles  operational setting 1
# 0                1               1                34.9983  \
# 1                1               2                41.9982
# 2                1               3                24.9988
# 3                1               4                42.0077
# 4                1               5                25.0005
# ...            ...             ...                    ...
# 53754          260             312                20.0037
# 53755          260             313                10.0022
# 53756          260             314                25.0041
# 53757          260             315                25.0033
# 53758          260             316                35.0036
#
#        operational setting 2  operational setting 3  sensor measurement 1
# 0                     0.8400                  100.0                449.44  \
# 1                     0.8408                  100.0                445.00
# 2                     0.6218                   60.0                462.54
# 3                     0.8416                  100.0                445.00
# 4                     0.6203                   60.0                462.54
# ...                      ...                    ...                   ...
# 53754                 0.7000                  100.0                491.19
# 53755                 0.2510                  100.0                489.05
# 53756                 0.6200                   60.0                462.54
# 53757                 0.6220                   60.0                462.54
# 53758                 0.8400                  100.0                449.44
#
#        sensor measurement 2  sensor measurement 3  sensor measurement 4
# 0                    555.32               1358.61               1137.23  \
# 1                    549.90               1353.22               1125.78
# 2                    537.31               1256.76               1047.45
# 3                    549.51               1354.03               1126.38
# 4                    537.07               1257.71               1047.93
# ...                     ...                   ...                   ...
# 53754                608.79               1495.60               1269.51
# 53755                605.81               1514.32               1324.12
# 53756                537.48               1276.24               1057.92
# 53757                537.84               1272.95               1066.30
# 53758                556.64               1374.61               1145.52
#
#        sensor measurement 5  ...  sensor measurement 12
# 0                      5.48  ...                 183.06  \
# 1                      3.91  ...                 130.42
# 2                      7.05  ...                 164.22
# 3                      3.91  ...                 130.72
# 4                      7.05  ...                 164.31
# ...                     ...  ...                    ...
# 53754                  9.35  ...                 314.05
# 53755                 10.52  ...                 371.22
# 53756                  7.05  ...                 163.74
# 53757                  7.05  ...                 164.37
# 53758                  5.48  ...                 183.09
#
#        sensor measurement 13  sensor measurement 14  sensor measurement 15
# 0                    2387.72                8048.56                 9.3461  \
# 1                    2387.66                8072.30                 9.3774
# 2                    2028.03                7864.87                10.8941
# 3                    2387.61                8068.66                 9.3528
# 4                    2028.00                7861.23                10.8963
# ...                      ...                    ...                    ...
# 53754                2389.02                8169.64                 9.3035
# 53755                2388.42                8245.36                 8.7586
# 53756                2030.33                7971.25                11.0657
# 53757                2030.35                7972.47                11.0537
# 53758                2390.38                8185.35                 9.3998
#
#        sensor measurement 16  sensor measurement 17  sensor measurement 18
# 0                       0.02                    334                   2223  \
# 1                       0.02                    330                   2212
# 2                       0.02                    309                   1915
# 3                       0.02                    329                   2212
# 4                       0.02                    309                   1915
# ...                      ...                    ...                    ...
# 53754                   0.03                    369                   2324
# 53755                   0.03                    374                   2319
# 53756                   0.02                    310                   1915
# 53757                   0.02                    311                   1915
# 53758                   0.02                    338                   2223
#
#        sensor measurement 19  sensor measurement 20  sensor measurement 21
# 0                     100.00                  14.73                 8.8071
# 1                     100.00                  10.41                 6.2665
# 2                      84.93                  14.08                 8.6723
# 3                     100.00                  10.59                 6.4701
# 4                      84.93                  14.13                 8.5286
# ...                      ...                    ...                    ...
# 53754                 100.00                  24.36                14.5189
# 53755                 100.00                  28.10                16.9454
# 53756                  84.93                  14.19                 8.5503
# 53757                  84.93                  14.05                 8.3729
# 53758                 100.00                  14.75                 8.8446
#
# [53759 rows x 26 columns]

# %%
X2_st = preprocessing.StandardScaler().fit(X2)
X2_st = X2_st.transform(X2)

X2_st = pd.DataFrame(X2_st)
X2_st.columns = ['unit number', 'time in cycles', 'operational setting 1', 'operational setting 2', 'operational setting 3', 'sensor measurement 1', 'sensor measurement 2', 'sensor measurement 3', 'sensor measurement 4', 'sensor measurement 5', 'sensor measurement 6', 'sensor measurement 7', 'sensor measurement 8', 'sensor measurement 9', 'sensor measurement 10', 'sensor measurement 11', 'sensor measurement 12', 'sensor measurement 13', 'sensor measurement 14', 'sensor measurement 15', 'sensor measurement 16', 'sensor measurement 17', 'sensor measurement 18', 'sensor measurement 19', 'sensor measurement 20', 'sensor measurement 21']

X2_st.drop(columns = X2_st.columns[0], axis= 1 , inplace= True)
X2_st.drop(columns = X2_st.columns[0], axis= 1 , inplace= True)

# %%
X2_st
# Out:
#        operational setting 1  operational setting 2  operational setting 3
# 0                   0.745895               0.864298               0.418187  \
# 1                   1.220553               0.866878               0.418187
# 2                   0.067836               0.160457              -2.391275
# 3                   1.221198               0.869459               0.418187
# 4                   0.067951               0.155618              -2.391275
# ...                      ...                    ...                    ...
# 53754              -0.270878               0.412704               0.418187
# 53755              -0.949073              -1.035622               0.418187
# 53756               0.068195               0.154650              -2.391275
# 53757               0.068141               0.161102              -2.391275
# 53758               0.746254               0.864298               0.418187
#
#        sensor measurement 1  sensor measurement 2  sensor measurement 3
# 0                 -0.889378             -0.653071             -0.579176  \
# 1                 -1.057627             -0.798422             -0.630051
# 2                 -0.392968             -1.136055             -1.540521
# 3                 -1.057627             -0.808881             -0.622406
# 4                 -0.392968             -1.142491             -1.531554
# ...                     ...                   ...                   ...
# 53754              0.692693              0.780862              0.713849
# 53755              0.611600              0.700946              0.890544
# 53756             -0.392968             -1.131496             -1.356652
# 53757             -0.392968             -1.121841             -1.387706
# 53758             -0.889378             -0.617672             -0.428155
#
#        sensor measurement 4  sensor measurement 5  sensor measurement 6
# 0                 -0.572622             -0.706177             -0.662907  \
# 1                 -0.668741             -1.140622             -1.084502
# 2                 -1.326301             -0.271732             -0.475122
# 3                 -0.663705             -1.140622             -1.084502
# 4                 -1.322271             -0.271732             -0.473281
# ...                     ...                   ...                   ...
# 53754              0.537834              0.364716              0.379114
# 53755              0.996270              0.688475              0.717863
# 53756             -1.238408             -0.271732             -0.471440
# 53757             -1.168060             -0.271732             -0.471440
# 53758             -0.503029             -0.706177             -0.661066
#
#        sensor measurement 7  ...  sensor measurement 12
# 0                 -0.602496  ...              -0.603008  \
# 1                 -0.986938  ...              -0.985404
# 2                 -0.732150  ...              -0.739869
# 3                 -0.987280  ...              -0.983225
# 4                 -0.736670  ...              -0.739215
# ...                     ...  ...                    ...
# 53754              0.351999  ...               0.348551
# 53755              0.752399  ...               0.763855
# 53756             -0.736259  ...              -0.743356
# 53757             -0.738314  ...              -0.738779
# 53758             -0.604619  ...              -0.602790
#
#        sensor measurement 13  sensor measurement 14  sensor measurement 15
# 0                   0.415116              -0.212615               0.021948  \
# 1                   0.414648               0.067215               0.063719
# 2                  -2.393490              -2.377822               2.087798
# 3                   0.414257               0.024309               0.030890
# 4                  -2.393724              -2.420728               2.090734
# ...                      ...                    ...                    ...
# 53754               0.425267               1.214589              -0.034903
# 53755               0.420582               2.107123              -0.762087
# 53756              -2.375530              -1.123891               2.316803
# 53757              -2.375374              -1.109510               2.300789
# 53758               0.435887               1.399768               0.093612
#
#        sensor measurement 16  sensor measurement 17  sensor measurement 18
# 0                  -0.705933              -0.515579              -0.039954  \
# 1                  -0.705933              -0.659701              -0.115645
# 2                  -0.705933              -1.416342              -2.159318
# 3                  -0.705933              -0.695731              -0.115645
# 4                  -0.705933              -1.416342              -2.159318
# ...                      ...                    ...                    ...
# 53754               1.416565               0.745489               0.655032
# 53755               1.416565               0.925641               0.620627
# 53756              -0.705933              -1.380311              -2.159318
# 53757              -0.705933              -1.344281              -2.159318
# 53758              -0.705933              -0.371457              -0.039954
#
#        sensor measurement 19  sensor measurement 20  sensor measurement 21
# 0                   0.418187              -0.613958              -0.619148
# 1                   0.418187              -1.051681              -1.048190
# 2                  -2.391275              -0.679819              -0.641912
# 3                   0.418187              -1.033443              -1.013808
# 4                  -2.391275              -0.674753              -0.666180
# ...                      ...                    ...                    ...
# 53754               0.418187               0.361801               0.345429
# 53755               0.418187               0.740757               0.755203
# 53756              -2.391275              -0.668673              -0.662515
# 53757              -2.391275              -0.682859              -0.692473
# 53758               0.418187              -0.611931              -0.612815
#
# [53759 rows x 24 columns]

# %% [markdown]
# ### *Этап 4 - Построение модели автокодировщика*

# %%
from tensorflow.keras import layers
from tensorflow.keras import regularizers

# %%
input_dim = len(X1_st.columns)


autoencoder = tf.keras.models.Sequential([
    tf.keras.layers.Dense(input_dim, activation='elu', input_shape=(input_dim, )), 
    tf.keras.layers.Dense(18, activation='elu'),
    tf.keras.layers.Dense(12, activation='elu'),
    tf.keras.layers.Dense(6, activation='elu'),
    tf.keras.layers.Dense(2, activation='elu'),
    
    # reconstruction / decode
    tf.keras.layers.Dense(6, activation='elu'),
    tf.keras.layers.Dense(12, activation='elu'),
    tf.keras.layers.Dense(18, activation='elu'),
    tf.keras.layers.Dense(input_dim, activation='elu')
])


autoencoder.compile(optimizer = "adam", 
                    loss = "mse",
                    metrics = ["acc"])


autoencoder.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_54 (Dense)            (None, 24)                600
#
#  dense_55 (Dense)            (None, 18)                450
#
#  dense_56 (Dense)            (None, 12)                228
#
#  dense_57 (Dense)            (None, 6)                 78
#
#  dense_58 (Dense)            (None, 2)                 14
#
#  dense_59 (Dense)            (None, 6)                 18
#
#  dense_60 (Dense)            (None, 12)                84
#
#  dense_61 (Dense)            (None, 18)                234
#
#  dense_62 (Dense)            (None, 24)                456
#
# =================================================================
# Total params: 2,162
# Trainable params: 2,162
# Non-trainable params: 0
# _________________________________________________________________

# %%
import datetime


log_dir = "content/logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

tensorboard_callback = tf.keras.callbacks.TensorBoard(
    log_dir=log_dir, histogram_freq=1, profile_batch = (10,100)
)

# %% [markdown]
# ### *Этап 5 - Обучение модели*

# %%
# tensorboard --logdir content/logs/

# %%
# autoencoder.fit(X1_train_st, validation_data=X1_train_st, epochs=230, callbacks=[tensorboard_callback])

history = autoencoder.fit(
    X1_st, X1_st,
    shuffle = True,
    epochs = 150,
    batch_size = 200,
    callbacks = [tensorboard_callback],
    validation_data=(X2_st, X2_st)
);
# Out:
# Epoch 1/150
# 104/104 [==============================] - 3s 26ms/step - loss: 0.2092 - acc: 0.3339 - val_loss: 1.2897 - val_acc: 0.1509
# Epoch 2/150
# 104/104 [==============================] - 2s 23ms/step - loss: 0.2091 - acc: 0.3344 - val_loss: 1.2724 - val_acc: 0.1506
# Epoch 3/150
# 104/104 [==============================] - 2s 23ms/step - loss: 0.2093 - acc: 0.3338 - val_loss: 1.2455 - val_acc: 0.1502
# Epoch 4/150
# 104/104 [==============================] - 2s 23ms/step - loss: 0.2090 - acc: 0.3315 - val_loss: 1.2617 - val_acc: 0.1505
# Epoch 5/150
# 104/104 [==============================] - 2s 22ms/step - loss: 0.2088 - acc: 0.3344 - val_loss: 1.2798 - val_acc: 0.1501
# Epoch 6/150
# 104/104 [==============================] - 2s 21ms/step - loss: 0.2088 - acc: 0.3338 - val_loss: 1.2778 - val_acc: 0.1507
# Epoch 7/150
# 104/104 [==============================] - 2s 21ms/step - loss: 0.2088 - acc: 0.3367 - val_loss: 1.2553 - val_acc: 0.1499
# Epoch 8/150
# 104/104 [==============================] - 2s 21ms/step - loss: 0.2089 - acc: 0.3343 - val_loss: 1.2598 - val_acc: 0.1509
# Epoch 9/150
# 104/104 [==============================] - 2s 22ms/step - loss: 0.2089 - acc: 0.3307 - val_loss: 1.2644 - val_acc: 0.1503
# Epoch 10/150
# 104/104 [==============================] - 2s 21ms/step - loss: 0.2088 - acc: 0.3352 - val_loss: 1.2590 - val_acc: 0.1508
# Epoch 11/150
# 104/104 [==============================] - 2s 22ms/step - loss: 0.2085 - acc: 0.3356 - val_loss: 1.2214 - val_acc: 0.1517
# Epoch 12/150
# 104/104 [==============================] - 2s 21ms/step - loss: 0.2085 - acc: 0.3348 - val_loss: 1.2260 - val_acc: 0.1507
# Epoch 13/150
# 104/104 [==============================] - 2s 22ms/step - loss: 0.2084 - acc: 0.3342 - val_loss: 1.2461 - val_acc: 0.1501
# Epoch 14/150
# 104/104 [==============================] - 2s 22ms/step - loss: 0.2085 - acc: 0.3356 - val_loss: 1.2678 - val_acc: 0.1466
# Epoch 15/150
# 104/104 [==============================] - 2s 23ms/step - loss: 0.2083 - acc: 0.3358 - val_loss: 1.2701 - val_acc: 0.1478
# Epoch 16/150
# 104/104 [==============================] - 2s 22ms/step - loss: 0.2085 - acc: 0.3339 - val_loss: 1.2798 - val_acc: 0.1487
# Epoch 17/150
# 104/104 [==============================] - 2s 22ms/step - loss: 0.2084 - acc: 0.3351 - val_loss: 1.2393 - val_acc: 0.1500
# Epoch 18/150
# 104/104 [==============================] - 2s 22ms/step - loss: 0.2083 - acc: 0.3330 - val_loss: 1.2491 - val_acc: 0.1506
# Epoch 19/150
# 104/104 [==============================] - 2s 22ms/step - loss: 0.2084 - acc: 0.3338 - val_loss: 1.2280 - val_acc: 0.1506
# Epoch 20/150
# 104/104 [==============================] - 2s 22ms/step - loss: 0.2086 - acc: 0.3338 - val_loss: 1.1798 - val_acc: 0.1501
# Epoch 21/150
# 104/104 [==============================] - 2s 22ms/step - loss: 0.2085 - acc: 0.3322 - val_loss: 1.1743 - val_acc: 0.1503
# Epoch 22/150
# 104/104 [==============================] - 2s 21ms/step - loss: 0.2082 - acc: 0.3348 - val_loss: 1.1738 - val_acc: 0.1504
# Epoch 23/150
# 104/104 [==============================] - 2s 21ms/step - loss: 0.2083 - acc: 0.3370 - val_loss: 1.2025 - val_acc: 0.1501
# Epoch 24/150
# 104/104 [==============================] - 2s 21ms/step - loss: 0.2081 - acc: 0.3371 - val_loss: 1.2041 - val_acc: 0.1501
# Epoch 25/150
# 104/104 [==============================] - 2s 21ms/step - loss: 0.